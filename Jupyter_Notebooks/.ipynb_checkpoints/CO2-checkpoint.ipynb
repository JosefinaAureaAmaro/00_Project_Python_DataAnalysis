# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import csv

# %%
csv_path = "../Project_1_AirPollution_vs_GDPperCapita/WDIData.csv"
WDIData_df = pd.read_csv(csv_path)
WDIData_df.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  2005 PPP conversion factor, GDP (LCU per inter...      PA.NUS.PPP.05   NaN
# 1  2005 PPP conversion factor, private consumptio...  PA.NUS.PRVT.PP.05   NaN
# 2  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2009       2010       2011  \
# 0   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
# 2   NaN   NaN   NaN   NaN   NaN  ...  81.844982  82.407647  82.827636
# ...

# %%
WDIData_df_headers=list(WDIData_df.columns.values)

# %%
WDIData_df_years = WDIData_df_headers[-59:]

# %%
WDIData_df_years_drop = WDIData_df_years[0:51]

# %%
WDIData_df_years_drop_2018 = list([WDIData_df_years[-1]])

# %%
WDIData_df_drop = WDIData_df_years_drop + WDIData_df_years_drop_2018

# %%
WDIData_df_1= WDIData_df.drop(WDIData_df_drop,axis=1)

# %%
WDIData_df_1.head(10)
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
# 5   Arab World          ARB
# 6   Arab World          ARB
# 7   Arab World          ARB
# 8   Arab World          ARB
# 9   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  \
# 0  2005 PPP conversion factor, GDP (LCU per inter...      PA.NUS.PPP.05
# 1  2005 PPP conversion factor, private consumptio...  PA.NUS.PRVT.PP.05
# 2  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 5  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 6  Account ownership at a financial institution o...     FX.OWN.TOTL.ZS
# ...

# %%
Indicator_Name =  WDIData_df_1['Indicator Name']=="CO2 emissions (metric tons per capita)"

Indicator_Name.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Indicator Name, dtype: bool

# %%
WDIData_df_2 = WDIData_df_1[Indicator_Name]

# %%
WDIData_df_2.shape
# Out:
# (264, 11)

# %%
WDIData_df_2.head(10)
# Out:
#                                         Country Name Country Code  \
# 206                                       Arab World          ARB
# 1805                          Caribbean small states          CSS
# 3404                  Central Europe and the Baltics          CEB
# 5003                      Early-demographic dividend          EAR
# 6602                             East Asia & Pacific          EAS
# 8201     East Asia & Pacific (excluding high income)          EAP
# 9800      East Asia & Pacific (IDA & IBRD countries)          TEA
# 11399                                      Euro area          EMU
# 12998                          Europe & Central Asia          ECS
# 14597  Europe & Central Asia (excluding high income)          ECA
#
#                                Indicator Name  Indicator Code      2011  \
# 206    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  4.537755
# 1805   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  9.143734
# ...

# %%
csv_path_2 = "../Project_1_AirPollution_vs_GDPperCapita/WDI_Country_Code_and_Names.csv"
Country_df = pd.read_csv(csv_path)
Country_df.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  2005 PPP conversion factor, GDP (LCU per inter...      PA.NUS.PPP.05   NaN
# 1  2005 PPP conversion factor, private consumptio...  PA.NUS.PRVT.PP.05   NaN
# 2  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2009       2010       2011  \
# 0   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
# 2   NaN   NaN   NaN   NaN   NaN  ...  81.844982  82.407647  82.827636
# ...

# %%
Country_df_headers=list(Country_df.columns.values)

# %%
Country_df_years = Country_df_headers[-59:]

# %%
Country_df_years_drop = Country_df_years[0:52]

# %%
Country_df_years_drop_2018 = list([WDIData_df_years[-1]])

# %%
Country_df_drop = Country_df_years_drop + Country_df_years_drop_2018

# %%
Country_df_1= Country_df.drop(Country_df_drop,axis=1)

# %%
Country_df_1.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  \
# 0  2005 PPP conversion factor, GDP (LCU per inter...      PA.NUS.PPP.05
# 1  2005 PPP conversion factor, private consumptio...  PA.NUS.PRVT.PP.05
# 2  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
#
#         2012       2013       2014       2015       2016  2017
# 0        NaN        NaN        NaN        NaN        NaN   NaN
# 1        NaN        NaN        NaN        NaN        NaN   NaN
# 2  83.169227  83.587141  83.954293  84.230630  84.570425   NaN
# 3  87.288244  88.389705  88.076774  88.517967  88.768654   NaN
# ...

# %%
Indicator_Name_2 =  Country_df_1['Indicator Name']=="Population, total"
Indicator_Name_2.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Indicator Name, dtype: bool

# %%
Country_df_2 = Country_df_1[Indicator_Name_2]

# %%
Country_df_2.shape
# Out:
# (264, 10)

# %%
Country_df_2.head()
# Out:
#                         Country Name Country Code     Indicator Name  \
# 1143                      Arab World          ARB  Population, total
# 2742          Caribbean small states          CSS  Population, total
# 4341  Central Europe and the Baltics          CEB  Population, total
# 5940      Early-demographic dividend          EAR  Population, total
# 7539             East Asia & Pacific          EAS  Population, total
#
#      Indicator Code          2012          2013          2014          2015  \
# 1143    SP.POP.TOTL  3.733070e+08  3.817021e+08  3.900430e+08  3.983050e+08
# 2742    SP.POP.TOTL  7.074129e+06  7.118888e+06  7.162679e+06  7.204948e+06
# 4341    SP.POP.TOTL  1.039353e+08  1.037137e+08  1.034962e+08  1.032578e+08
# 5940    SP.POP.TOTL  2.997066e+09  3.040701e+09  3.084236e+09  3.127579e+09
# 7539    SP.POP.TOTL  2.237073e+09  2.252293e+09  2.267717e+09  2.283073e+09
#
#               2016          2017
# 1143  4.064527e+08  4.144919e+08
# ...

# %%
merge_df = pd.merge(WDIData_df_2, Country_df_2, on="Country Code", how="inner")
merge_df
# Out:
#                                         Country Name_x Country Code  \
# 0                                           Arab World          ARB
# 1                               Caribbean small states          CSS
# 2                       Central Europe and the Baltics          CEB
# 3                           Early-demographic dividend          EAR
# 4                                  East Asia & Pacific          EAS
# 5          East Asia & Pacific (excluding high income)          EAP
# 6           East Asia & Pacific (IDA & IBRD countries)          TEA
# 7                                            Euro area          EMU
# 8                                Europe & Central Asia          ECS
# 9        Europe & Central Asia (excluding high income)          ECA
# 10        Europe & Central Asia (IDA & IBRD countries)          TEC
# 11                                      European Union          EUU
# 12            Fragile and conflict affected situations          FCS
# ...

# %%
merge_df.to_csv(index=False)
# Out:
# 'Country Name_x,Country Code,Indicator Name_x,Indicator Code_x,2011,2012_x,2013_x,2014_x,2015_x,2016_x,2017_x,Country Name_y,Indicator Name_y,Indicator Code_y,2012_y,2013_y,2014_y,2015_y,2016_y,2017_y\r\nArab World,ARB,CO2 emissions (metric tons per capita),EN.ATM.CO2E.PC,4.537755236000001,4.813630727,4.650474168,4.860233832,,,,Arab World,"Population, total",SP.POP.TOTL,373306993.0,381702086.0,390043028.0,398304960.0,406452690.0,414491886.0\r\nCaribbean small states,CSS,CO2 emissions (metric tons per capita),EN.ATM.CO2E.PC,9.143734221,8.886377531,9.138025489,8.884541385,,,,Caribbean small states,"Population, total",SP.POP.TOTL,7074129.0,7118888.0,7162679.0,7204948.0,7245472.0,7284294.0\r\nCentral Europe and the Baltics,CEB,CO2 emissions (metric tons per capita),EN.ATM.CO2E.PC,6.864349465,6.504366995,6.344838262000001,6.14888254,,,,Central Europe and the Baltics,"Population, total",SP.POP.TOTL,103935318.0,103713726.0,103496179.0,103257751.0,102994343.0,102735349.0\r\nEarly-demographic
# ...

# %%
directory='C:\Users\jwang\Desktop\Bootcamp\Classwork\homework\Project_1_AirPollution_vs_GDPperCapita\Project_1_AirPollution_vs_GDPperCapita\merge_df.csv'
# Out:
#   File "<ipython-input-176-33e4b8120789>", line 1
#     directory='C:\Users\jwang\Desktop\Bootcamp\Classwork\homework\Project_1_AirPollution_vs_GDPperCapita\Project_1_AirPollution_vs_GDPperCapita\merge_df.csv'
#              ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
