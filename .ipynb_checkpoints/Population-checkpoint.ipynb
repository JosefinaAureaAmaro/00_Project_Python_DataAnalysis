# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
file = "Populationdata.csv"
file_df = pd.read_csv(file,encoding = "ISO-8859-1")
file_df.head()
# Out:
#                      Country Name Country Code     Indicator Name  \
# 0                      Arab World          ARB  Population, total
# 1          Caribbean small states          CSS  Population, total
# 2  Central Europe and the Baltics          CEB  Population, total
# 3      Early-demographic dividend          EAR  Population, total
# 4             East Asia & Pacific          EAS  Population, total
#
#   Indicator Code          1960          1961          1962          1963  \
# 0    SP.POP.TOTL  9.249093e+07  9.504450e+07  9.768229e+07  1.004111e+08
# 1    SP.POP.TOTL  4.198307e+06  4.277802e+06  4.357746e+06  4.436804e+06
# 2    SP.POP.TOTL  9.140176e+07  9.223274e+07  9.300950e+07  9.384002e+07
# 3    SP.POP.TOTL  9.792874e+08  1.002524e+09  1.026587e+09  1.051415e+09
# 4    SP.POP.TOTL  1.040034e+09  1.043597e+09  1.058046e+09  1.083797e+09
#
#            1964          1965  ...          2009          2010          2011  \
# ...

# %%
file_df1 = file_df.loc[:,['Country Name','Country Code','Indicator Name','Indicator Code','2012','2013','2014','2015','2016','2017']]
file_df1.head()
# Out:
#                      Country Name Country Code     Indicator Name  \
# 0                      Arab World          ARB  Population, total
# 1          Caribbean small states          CSS  Population, total
# 2  Central Europe and the Baltics          CEB  Population, total
# 3      Early-demographic dividend          EAR  Population, total
# 4             East Asia & Pacific          EAS  Population, total
#
#   Indicator Code          2012          2013          2014          2015  \
# 0    SP.POP.TOTL  3.733070e+08  3.817021e+08  3.900430e+08  3.983050e+08
# 1    SP.POP.TOTL  7.074129e+06  7.118888e+06  7.162679e+06  7.204948e+06
# 2    SP.POP.TOTL  1.039353e+08  1.037137e+08  1.034962e+08  1.032578e+08
# 3    SP.POP.TOTL  2.997066e+09  3.040701e+09  3.084236e+09  3.127579e+09
# 4    SP.POP.TOTL  2.237073e+09  2.252293e+09  2.267717e+09  2.283073e+09
#
#            2016          2017
# 0  4.064527e+08  4.144919e+08
# 1  7.245472e+06  7.284294e+06
# 2  1.029943e+08  1.027353e+08
# ...

# %%
file_df1_sort = file_df1.sort_values(by=['2017'],ascending=False)
file_df1_sort
# Out:
#                                      Country Name Country Code  \
# 46                                          World          WLD
# 16                               IDA & IBRD total          IBT
# 25                            Low & middle income          LMY
# 31                                  Middle income          MIC
# 15                                      IBRD only          IBD
# 3                      Early-demographic dividend          EAR
# 27                            Lower middle income          LMC
# 45                            Upper middle income          UMC
# 4                             East Asia & Pacific          EAS
# 20                      Late-demographic dividend          LTE
# 5     East Asia & Pacific (excluding high income)          EAP
# 6      East Asia & Pacific (IDA & IBRD countries)          TEA
# 40                                     South Asia          SAS
# 41                        South Asia (IDA & IBRD)          TSA
# ...
